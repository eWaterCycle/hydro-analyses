# %%
# REQUIREMENTS:
# 1. NetCDF ensemble output data
# 2. GRDC discharge data
# !python --version
# Out:
# Python 3.6.6

# %%
#Import Modules
import os
import sys
import xarray as xr
import numpy as np
import pandas as pd
import holoviews as hv

import geoviews as gv
import geoviews.feature as gf

from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file

import hydrostats.data as hydrod
import hydrostats.visual as hydrov
import hydrostats.ens_metrics as em
import HydroErr as he
import matplotlib.pyplot as plt
from scipy.stats import norm
from ranky import rankz

import cartopy
from cartopy import crs as ccrs

from stations import Station

hv.notebook_extension('bokeh')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
# It is assumed that the WorkingPath has 2 subdirectories:
# - 'GRDCdat_day' containing GRDC files. Each file has name <station_id>.day and contains daily readings
# - 'netcdf' containing netcdf ensemble files. Each ensemble member is represented by one file with name 'discharge*???.nc'
#    where the 3 characters ??? identify the ensemble member.
#    In addition 'netcdf' contains files with  ensemble statistics with names 'discharge*Out.nc'

WorkingPath = r'D:/sbranchett/Jerom/' #set working directory

# %%
#Initialise the Stations of interest
GRDC_dir = os.path.join(WorkingPath,'GRDCdat_day') # directory holding the <station_id>.day file

stations = []
stations.append(Station(GRDC_dir, 6435060, 'Lobith (Rhine, Europe)'))
stations.append(Station(GRDC_dir, 6242401, 'Kienstock (Danube, Europe)'))
stations.append(Station(GRDC_dir, 4208025, 'Arctic Red River (Mackenzie, North America)'))
stations.append(Station(GRDC_dir, 4127501, 'Thebes (Mississippi, North America)'))
stations.append(Station(GRDC_dir, 3618000, 'Jatuarana (Amazon, South America)'))
stations.append(Station(GRDC_dir, 5204250, 'Louth (Darling, Australia)'))
stations.append(Station(GRDC_dir, 1134100, 'Koulikoro (Niger, Africa)'))
stations.append(Station(GRDC_dir, 2903430, 'Stolb (Lena, Asia)'))
# Out:
# Changing station label from 'LOBITH - RHINE RIVER - NL' to 'Lobith (Rhine, Europe)'
# Changing station label from 'KIENSTOCK - DANUBE RIVER - AT' to 'Kienstock (Danube, Europe)'
# Changing station label from 'ARCTIC RED RIVER - MACKENZIE RIVER - CA' to 'Arctic Red River (Mackenzie, North America)'
# Changing station label from 'THEBES, IL - MISSISSIPPI RIVER - US' to 'Thebes (Mississippi, North America)'
# Changing station label from 'JATUARANA - AMAZONAS - BR' to 'Jatuarana (Amazon, South America)'
# Changing station label from 'LOUTH - DARLING RIVER - AU' to 'Louth (Darling, Australia)'
# Changing station label from 'KOULIKORO - NIGER - ML' to 'Koulikoro (Niger, Africa)'
# Changing station label from 'STOLB - LENA - RU' to 'Stolb (Lena, Asia)'

# %%
#print out the metadata
#for station in stations:
#    print("Metadata for station ", station.station_id)
#    for key in station.metadata:
#        print("--- ", str(key).ljust(30), station.metadata[key])

# %%
#read in the selected netcdf simulations
netcdf_dir = os.path.join(WorkingPath,'netcdf') # directory holding the <station_id>.day file
data_var, data_stats = Station.init_netcdf(netcdf_dir)

for station in stations:
    station.netcdf_data()
    
# find the first and last date of the ensemble simulation
# this assumes that all ensemble members have the same date range
first_date = str(stations[0].array.time.values[0])[:10]
last_date = str(stations[0].array.time.values[-1])[:10]

# %%
#Create plot for each subbasin showing the ensemble spread.

#Basin Plots
plots = []
    
for station in stations:
    curves = [hv.Curve(station.ds[data_var[i]], label=data_var[i]) for i in range(len(data_var))]

    plots.append(hv.Area((station.ds['time'], station.max, station.min),\
                         kdims=['Date '+first_date[:4], 'Discharge ['+station.metadata["units"]+"]"], 
                         vdims=[station.name+'_max', station.name+'_min']).options(color='blue', alpha=0.4, title_format=station.label) *\
                         hv.Overlay.from_values(curves))

# %%
# %%opts Layout [shared_axes=False] Overlay [width=450, height=400 legend_position='top_right', show_title=True, fontsize={'legend':6, 'title':10, 'xlabel':10, 'ylabel':10, 'ticks':10}] Curve (muted_alpha=0.5 muted_color='black')
#
# hv.Layout(plots).cols(2)
# Out:
# :Layout
#    .Overlay.I    :Overlay
#       .Area.I             :Area   [Date 2017,Discharge [m³/s]]   (LOBITH_max,LOBITH_min)
#       .Curve.Discharge_13 :Curve   [time]   (discharge_13)
#       .Curve.Discharge_14 :Curve   [time]   (discharge_14)
#       .Curve.Discharge_15 :Curve   [time]   (discharge_15)
#       .Curve.Discharge_16 :Curve   [time]   (discharge_16)
#       .Curve.Discharge_17 :Curve   [time]   (discharge_17)
#       .Curve.Discharge_18 :Curve   [time]   (discharge_18)
#       .Curve.Discharge_19 :Curve   [time]   (discharge_19)
#       .Curve.Discharge_20 :Curve   [time]   (discharge_20)
#    .Overlay.II   :Overlay
#       .Area.I             :Area   [Date 2017,Discharge [m³/s]]   (KIENSTOCK_max,KIENSTOCK_min)
#       .Curve.Discharge_13 :Curve   [time]   (discharge_13)
#       .Curve.Discharge_14 :Curve   [time]   (discharge_14)
#       .Curve.Discharge_15 :Curve   [time]   (discharge_15)
#       .Curve.Discharge_16 :Curve   [time]   (discharge_16)
# ...

# %%
#read in the observed grdc data for a specified date range
first_date = '2000-11-22'
last_date = '2000-11-30'

#todo there is a big hack in grdc_data that collects 2000 data and sells it as 2017 data. This must be removed!!
for station in stations:
    station.obs_data = station.grdc_data(first_date, last_date)

first_date = str(stations[0].array.time.values[0])[:10]
last_date = str(stations[0].array.time.values[-1])[:10]

# %%
#Create observation and simulation plot with mean and std

plots2 = []
for station in stations:
    plots2.append(hv.Area((station.ds['time'], station.min, station.max), \
                    vdims=[station.name+'.min', station.name+'.max'], \
                    kdims=['Date '+first_date[:4], 'Discharge ['+station.metadata["units"]+"]"]).options(color='blue', alpha=0.4, title_format=station.label) *\
                  hv.Area((station.ds['time'], station.max, station.std_high), \
                    vdims=['maxima', station.name+'std_high']).options(color='red', alpha=0.2) *\
                  hv.Area((station.ds['time'], station.min, station.std_low), \
                    vdims=['maxima', station.name+'std_low']).options(color='red', alpha=0.2) *\
                  hv.Curve(station.mean, label='ens_mean').options(line_width = 5, color='blue')*\
                  hv.Curve(station.std_low, label='ens_Std').options(line_width = 2, color='red')*\
                  hv.Curve(station.std_high, label='ens_Std').options(line_width = 2, color='red')*\
                  hv.Curve(station.obs_data, label='obs').options(line_width = 5, color='purple'))

# %%
# %%opts Layout [shared_axes=False] Overlay [width=450, height=400 legend_position='top_right', show_title=True, fontsize={'legend':6, 'title':10, 'xlabel':10, 'ylabel':10, 'ticks':10}] Curve (muted_alpha=0.5 muted_color='black')
#
# hv.Layout(plots2).cols(2)
# Out:
# :Layout
#    .Overlay.I    :Overlay
#       .Area.I           :Area   [Date 2017,Discharge [m³/s]]   (LOBITH.min,LOBITH.max)
#       .Area.II          :Area   [x]   (maxima,LOBITHstd_high)
#       .Area.III         :Area   [x]   (maxima,LOBITHstd_low)
#       .Curve.Ens_mean   :Curve   [time]   (dischargeEnsMeanOut)
#       .Curve.Ens_Std.I  :Curve   [time]   (dischargeEnsStdOut)
#       .Curve.Ens_Std.II :Curve   [time]   (y)
#       .Curve.Obs        :Curve   [time]   (y)
#    .Overlay.II   :Overlay
#       .Area.I           :Area   [Date 2017,Discharge [m³/s]]   (KIENSTOCK.min,KIENSTOCK.max)
#       .Area.II          :Area   [x]   (maxima,KIENSTOCKstd_high)
#       .Area.III         :Area   [x]   (maxima,KIENSTOCKstd_low)
#       .Curve.Ens_mean   :Curve   [time]   (dischargeEnsMeanOut)
#       .Curve.Ens_Std.I  :Curve   [time]   (dischargeEnsStdOut)
#       .Curve.Ens_Std.II :Curve   [time]   (y)
#       .Curve.Obs        :Curve   [time]   (y)
#    .Overlay.III  :Overlay
# ...

# %%
#General statistics NSE
for station in stations:
    sim = station.mean.values
    obs = station.obs_data.values
    print (str(he.nse(sim, obs))+' '+station.label)
# Out:
# -5.969944903658595 Lobith (Rhine, Europe)
# -299.8550353337715 Kienstock (Danube, Europe)
# -54.877919077448034 Arctic Red River (Mackenzie, North America)
# -1212.4475425016224 Thebes (Mississippi, North America)
# -1091.0104745085507 Jatuarana (Amazon, South America)
# -191.63734886203645 Louth (Darling, Australia)
# -0.6068941029684298 Koulikoro (Niger, Africa)
# -2037.9698596902115 Stolb (Lena, Asia)

# %%
# stack the observations and the ensemble results ready for plotting a rank histogram
for station in stations:
    station.stack = np.stack(station.array, axis=0) # ensemble stack
ens_stack = np.stack((station.stack for station in stations), axis=2)
obs_stack = np.stack((station.obs_data for station in stations), axis=1)

# %%
# see https://github.com/oliverangelil/rankhistogram/blob/master/README.md
no_time_steps = len(obs_stack)
no_stations = len(stations)

obs = np.array(obs_stack)
ensemble = np.array(ens_stack)

#mask = np.random.randint(0, 2, (no_time_steps, no_stations)) #masked where 0/false.
mask = np.ones((no_time_steps, no_stations)) # no mask, masked where 0/false

# feed into rankz function
result = rankz(obs, ensemble, mask)

# plot histogram
plt.bar(range(1,ensemble.shape[0]+2), result[0])
plt.xlabel("Rank of Observation")

# view histogram
plt.show()

# %% [markdown]
# ## For intepretation see page 13 of this ECMWF presentation:

# %%
from IPython.display import IFrame
IFrame("https://www.ecmwf.int/sites/default/files/elibrary/2017/17626-ensemble-verification-metrics.pdf#page=13",\
       width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="https://www.ecmwf.int/sites/default/files/elibrary/2017/17626-ensemble-verification-metrics.pdf#page=13"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Check using https://waderoberts123.github.io/Hydrostats/index.html
station_index = 4
graph_label = stations[station_index].label
obs_label = 'GRDC observation'
graph_label = stations[station_index].label
obs_df = pd.DataFrame(stations[station_index].obs_data.values)
obs_df = obs_df.set_index(stations[station_index].obs_data.time.values)
sim_df = pd.DataFrame(stations[station_index].ds_stats[data_stats[0]].values)
sim_df = sim_df.set_index(stations[station_index].ds_stats.time.values)

# %% [markdown]
# ### hydrostats.visual Module

# %%
merged_df = hydrod.merge_data(sim_df=sim_df, obs_df=obs_df, column_names=('Mean of Ensemble', 'GRDC observation'))

hydrov.plot(merged_data_df=merged_df,
    title='Hydrograph of Entire Time Series',
    linestyles=['r-', 'k-'],
    legend=('Mean of Ensemble', 'GRDC observation'),
    labels=[graph_label, 'Discharge ['+stations[station_index].metadata["units"]+"]"],
    metrics=['ME', 'NSE', 'SA'],
    grid=True)
plt.show()

# %%
hydrov.hist(merged_data_df=merged_df,
    num_bins=100,
    title='Histogram of Streamflows',
    legend=('Mean of Ensemble', 'GRDC observation'),
    labels=[graph_label, 'Discharge ['+stations[station_index].metadata["units"]+"]"],
    grid=True)
plt.show()

# %%
hydrov.scatter(merged_data_df=merged_df,
    grid=True,
    title='Scatter Plot (Normal Scale)',
    labels=[graph_label, 'Discharge ['+stations[station_index].metadata["units"]+"]"],
    line45=True,
    metrics=['ME', 'KGE (2012)'],
    best_fit=True)
plt.show()

# %%
hydrov.qqplot(merged_data_df=merged_df,
    title='Quantile-Quantile Plot of Data',
    xlabel='Mean of Ensemble Quantiles',
    ylabel='GRDC observation Quantiles',
    legend=True,
    figsize=(8, 6))
plt.show()

# %% [markdown]
# ### hydrostats.ens_metrics Module

# %%
ensemble_array = np.array(stations[station_index].array).transpose()
observed_array = np.array(stations[station_index].obs_data)

ens_me = em.ens_me(obs=observed_array, fcst_ens=ensemble_array)
print('Mean error between observed values and the ensemble mean:')
print(str(ens_me)+" "+stations[station_index].label)
print("")

ens_mae = em.ens_mae(obs=observed_array, fcst_ens=ensemble_array)
print('Mean absolute error between observed values and the ensemble mean:')
print(str(ens_mae)+" "+stations[station_index].label)
print("")

ens_mse = em.ens_mse(obs=observed_array, fcst_ens=ensemble_array)
print('Mean squared error between observed values and the ensemble mean:')
print(str(ens_mse)+" "+stations[station_index].label)
print("")

ens_rmse = em.ens_rmse(obs=observed_array, fcst_ens=ensemble_array)
print('Root mean squared error between observed values and the ensemble mean:')
print(str(ens_rmse)+" "+stations[station_index].label)
print("")

ens_pearson_r = em.ens_pearson_r(obs=observed_array, fcst_ens=ensemble_array)
print('Pearson correlation coefficient between observed values and the ensemble mean:')
print(str(ens_pearson_r)+" "+stations[station_index].label)
print("")
# Out:
# Mean error between observed values and the ensemble mean:
# -37435.36675347222 Jatuarana (Amazon, South America)
#
# Mean absolute error between observed values and the ensemble mean:
# 37435.36675347222 Jatuarana (Amazon, South America)
#
# Mean squared error between observed values and the ensemble mean:
# 1405130214.991806 Jatuarana (Amazon, South America)
#
# Root mean squared error between observed values and the ensemble mean:
# 37485.066559788924 Jatuarana (Amazon, South America)
#
# Pearson correlation coefficient between observed values and the ensemble mean:
# 0.740514922818304 Jatuarana (Amazon, South America)

# %%
crps_hersbach = em.crps_hersbach(obs=observed_array, fcst_ens=ensemble_array)
print('Continuous ranked probability score (CRPS) as per equation 25-27 in Hersbach et al. (2000):')
print(str(crps_hersbach)+" "+stations[station_index].label)
print("")

crps_kernel = em.crps_kernel(obs=observed_array, fcst_ens=ensemble_array)
print('Kernel representation of the continuous ranked probability score (CRPS):')
print(str(crps_kernel)+" \n"+stations[station_index].label)
print("")

#ens_crps = em.ens_crps(obs=observed_array, fcst_ens=ensemble_array)
#print('Ensemble-adjusted Continuous Ranked Probability Score (CRPS):')
#print(str(ens_crps)+" \n"+stations[station_index].label)
#print("")
#todo - why doesn't this work?

ens_brier = em.ens_brier(obs=observed_array, fcst_ens=ensemble_array, threshold=9000.)
print('Ensemble-adjusted Brier Score:')
print(str(ens_brier)+" \n"+stations[station_index].label)
print("")
#todo - how should this work?
# Out:
# Continuous ranked probability score (CRPS) as per equation 25-27 in Hersbach et al. (2000):
# {'crps': array([37215.65911865, 36272.8269043 , 34283.09594727, 32094.84155273,
#        34006.7947998 , 37736.69195557, 38051.59490967, 37805.40966797,
#        37695.74511719]), 'crpsMean1': 36129.1844414605, 'crpsMean2': 36129.18444146051} Jatuarana (Amazon, South America)
#
# Kernel representation of the continuous ranked probability score (CRPS):
# {'crps': array([37215.65960693, 36272.82397461, 34283.09887695, 32094.84350586,
#        34006.7947998 , 37736.69244385, 38051.59344482, 37805.40673828,
#        37695.74414062]), 'crpsAdjusted': array([37080.99044364, 36121.17829241, 34064.8563058 , 31866.15708705,
#        33817.79506138, 37542.82205636, 37844.0867048 , 37620.68582589,
#        37524.70814732]), 'crpsMean': 36129.18417019314, 'crpsAdjustedMean': 35942.58665829613}
# Jatuarana (Amazon, South America)
#
# Ensemble-adjusted Brier Score:
# [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ...

# %%
Ignore this part for Now.
# Out:
#   File "<ipython-input-23-5cbcd7600946>", line 1
#     Ignore this part for Now.
#               ^
# SyntaxError: invalid syntax

# %%
#def ensemble_normalize(station):
#    ls = station.keys()
#    del ls[0:3]
#    for f in ls:
#        norm = (station[f]-station[f].min())/(station[f].max()-station[f].min())
#        normhist = np.stack((norm), axis=0)
#    return norm
#
#lobith_norm = ensemble_normalize(stations[0])

for station in stations:
    station.norm = (station.mean-station.min)/(station.max-station.min) # is station[f] station.mean()?

# %%
#Take the mean of multiple years for certain dates (only necessary when up to date GRDC data is not available)
#todo - not yet used! This is what the hack was about
def grdc_mean(grdc_data):
    data = np.array([])
    subdata = np.array([])
    for k in ['-11-22','-11-23','-11-24','-11-25','-11-26','-11-27','-11-28','-11-29','-11-30']:
        for i in [2000,2001,2002,2003,2004,2005]:
            grdc = grdc_data.loc[str(i)+str(k)].mean()
            
            subdata = np.append(subdata, grdc)
        data = np.append(data, subdata.mean())
    return data
